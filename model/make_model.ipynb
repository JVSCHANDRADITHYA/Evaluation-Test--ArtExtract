# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
model = torch.nn.RNN(input_size=10, hidden_size=20, num_layers=2, batch_first=True)

# %%
model.all_weights
# Out:
# [[Parameter containing:
#   tensor([[-0.1461,  0.0657, -0.0409,  0.1952, -0.0729, -0.0193,  0.2039,  0.1511,
#             0.1578,  0.0488],
#           [ 0.2160,  0.1764,  0.1379, -0.0770,  0.0854, -0.0786,  0.1213,  0.1497,
#            -0.1971, -0.0850],
#           [ 0.1486,  0.0801,  0.1665,  0.1261, -0.0630, -0.1715,  0.0331,  0.1294,
#             0.2042,  0.1855],
#           [ 0.0766,  0.0821, -0.0875,  0.0923,  0.0621, -0.0320, -0.0855,  0.1026,
#            -0.1855,  0.0636],
#           [-0.0049,  0.0349,  0.0490,  0.0865,  0.0352,  0.0801, -0.1842,  0.0652,
#            -0.2210, -0.1021],
#           [ 0.0108,  0.0521, -0.0615,  0.0174,  0.0679,  0.1514, -0.0873,  0.1410,
#            -0.0555, -0.1125],
#           [ 0.1509, -0.0803, -0.0796,  0.0610, -0.0597, -0.0545,  0.0029,  0.1755,
#             0.0753,  0.0158],
#           [ 0.1110, -0.1661,  0.1216,  0.0336,  0.1492,  0.0816,  0.0705,  0.0550,
#            -0.0961,  0.0792],
# ...
